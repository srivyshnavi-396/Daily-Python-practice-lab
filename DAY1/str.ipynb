# %% [markdown]
# STRING

# %%
# text....>string

# %%
'''strings are one of the most fundamental data types we use
..>string is a sequence of characters enclosed in single or double quotes
for multiple lines we use triple quotes
..>it is used to store and manipulate text'''

# %%
'''
giving unequal quotes gives syntax error
..>" '''..>error
..>' "..>error
'''

# %%
# to quote a quote, we need to "escape" it, by preceding it with \.alternatively,
#we can use the other type of quotation marks.
'hi\'hello'
# Out:
# "hi'hello"

# %%
'does\'t'
# Out:
# "does't"

# %%
#\n means new line
'first.\nsecond'
# Out:
# 'first.\nsecond'

# %%
print('first.\nsecond.')# using print avoids special characters
# Out:
# first.
# second.

# %%
print('''
      hi
      hello 
      how''')
# Out:
#       hi
#       hello
#       how

# %%
print('''\
      hi
        hello
           how''')
# Out:
#       hi
#         hello
#            how

# %%
#CREATING A STRING
#it can be created using quotes
str = "hello"
print(str)
# Out:
# hello

# %%
#single quotes
str1 = 'hi'
str1
# Out:
# 'hi'

# %%
#double quotes
str2 = "how"
str2
# Out:
# 'how'

# %%
#triple quotes
str3 = '''hi
          hello
          how'''
str3
# Out:
# 'hi\n          hello\n          how'

# %%
str4 = ('mon'
        'tue'
        'wed')
str4
# Out:
# 'montuewed'

# %%
str5 = ('mon '
        'tue '
        'wed ')# to add space give space at word end

str5
# Out:
# 'mon tue wed '

# %% [markdown]
# * in STRING

# %%
# *(multiply operator)
#you can multiply a string by an integer to repeat it multiple times
#it is technically a form of repeated concatenation
#it is used to print the same string number of times
str6 = "hey "
str6*4
# Out:
# 'hey hey hey hey '

# %%
len(str6)
# Out:
# 4

# %%
str7 = str6*4
str7
# Out:
# 'hey hey hey hey '

# %%
len(str7)
# Out:
# 16

# %% [markdown]
# string concatenation

# %%
# +(plus operater)
# this is process of joining two or more strings together 
# to create a new string
# it add the element ene to end

# %%
#direct concatenation
s = 'hi'
s1 = 'hello'
r = s+s1
r
# Out:
# 'hihello'

# %%
#adding space manually
s = 'hi'
s1 = 'hello'
r = s+" "+s1
r
# Out:
# 'hi hello'

# %% [markdown]
# JOIN METHOD

# %%
# while the + operator is easy for two strings,
#it becomes ineffienct for more than two strings(like list of words)
#the .join() method is the professional way to handle this because 
# it is faster and more memory efficient

# %%
list = ["hey","hi","how are you"]
list
# Out:
# ['hey', 'hi', 'how are you']

# %%
sentence = " ".join(list)
sentence
# Out:
# 'hey hi how are you'

# %%
# NOTE : in order to add string with other types like integer initially
# convert it in to string

s + 10# raise type error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 4
#       1 # NOTE : in order to add string with other types like integer initially
#       2 # convert it in to string
# ----> 4 s + 10
#
# TypeError: can only concatenate str (not "int") to str

# %%
 (str(10))#type error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 (str(10))
#
# TypeError: 'str' object is not callable

# %%
f"hi : {10}"
# Out:
# 'hi : 10'

# %% [markdown]
# STRING INDEXING AND SLICING

# %%
#inorder to access string we can use indexing and slicing

# %%
str8 = "hello"
str8[0]
# Out:
# 'h'

# %%
str8[len(str8)-1]
# Out:
# 'o'

# %%
str8[-1]
# Out:
# 'o'

# %%
str8[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 str8[5]
#
# IndexError: string index out of range

# %%
str8
# Out:
# 'hello'

# %% [markdown]
# SLICING

# %%
str8[0:3]
# Out:
# 'hel'

# %%
str8[:-1]
# Out:
# 'hell'

# %%
str8[:]
# Out:
# 'hello'

# %%
str8[::-1]
# Out:
# 'olleh'

# %%
# UBDATE
str9 = "hello python"
str9[0:4] = "heyy"# string is immutable, it cannot be changed but can create another string
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 3
#       1 # UBDATE
#       2 str9 = "hello python"
# ----> 3 str9[0:4] = "heyy"
#
# TypeError: 'str' object does not support item assignment

# %%
str10 = str9

# %%
# DELETION
del str10

# %%
str9
# Out:
# 'hello python'

# %%
str10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 str10
#
# NameError: name 'str10' is not defined

# %% [markdown]
# METHODS

# %%
# transform methods
str8.upper()#convert to upper case
# Out:
# 'HELLO'

# %%
str8.lower()#convert to lower case
# Out:
# 'hello'

# %%
str8.capitalize()#capitalize only the first charecter
# Out:
# 'Hello'

# %%
sttr = "python world"

# %%
sttr
# Out:
# 'python world'

# %%
sttr.title()#capitalize first charecter of every word
# Out:
# 'Python World'

# %%
sttr.swapcase()#covert upper to lower and lower to upper
# Out:
# 'PYTHON WORLD'

# %%
sttr1 = "PythonWORLD"
sttr1
# Out:
# 'PythonWORLD'

# %%
sttr1.swapcase()
# Out:
# 'pYTHONworld'
