# %% [markdown]
# NUMERIC DATA TYPE

# %% [markdown]
# INTEGER

# %%
#it consists of 4 types
# int//float//complex//boolean

# %%
# value without decimal called int
i=4

# %%
i = 4
type(i)
# Out:
# int

# %% [markdown]
# FLOAT

# %%
# value with decimal called float
f = 1.1

# %%
f = 1.1
type(f)
# Out:
# float

# %%
# in float only e letter is allowed both(E&e)
#e to the power 0 mean 1
#e1 = 10 
#e2 = 100
#en ..>n=0s

# %%
f1 = 1e0#..>1 * 1
f1
# Out:
# 1.0

# %%
f2 = 1e1#1*10
f2
# Out:
# 10.0

# %%
f3 = 2e1
f3
# Out:
# 20.0

# %%
f4 = 1e2
f4
# Out:
# 100.0

# %%
f5 = 2.4e2#..2.4 *100..>2.4..>decimal means we can write 24/10 *100
#..>0 &0 cancel..>24*10 = 240

f5
# Out:
# 240.0

# %%
f6 = 2.5E2
f6
# Out:
# 250.0

# %%
f7 = 2b2# only e is allowed
f7
# Out:
#   Cell In[13], line 1
#     f7 = 2b2
#          ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# COMPLEX

# %%
'''In Python, the complex type is used to represent complex numbers, which consist of a real 
and an imaginary part.  
You can create complex numbers and perform mathematical operations on them using the 
built-in support for complex numbers. 
Creating a Complex Number 
A complex number is created by appending the letter j (or J) to the imaginary part. 
The format is:  z = real + imaginary*1j'''

# %%
# function is called with dot(.)

# %%
# in complex  1 + 2j
# 1 is called real part
# 2j is called imaginary part

# %%
c = 2 + 3j # j represent as square root of -1//imaginary part
type(c)
# Out:
# complex

# %%
'''Accessing the Real and Imaginary Parts 
You can access the real and imaginary parts of a complex number using the .real and .imag 
attributes:'''

# %%
c.real
# Out:
# 2.0

# %%
c.imag
# Out:
# 3.0

# %%
'''Operations with Complex Numbers 
You can perform various operations like addition, subtraction, multiplication, division, and 
more with complex numbers. Python handles these operations automatically. '''

# %%
e = 10 +2j
f = 20 + 3j
g = e + f
g# calculates real with real and imag with imag
# Out:
# (30+5j)

# %%
print(e-f)
# Out:
# (-10-1j)

# %%
print(e*f)
# Out:
# (194+70j)

# %%
print(e/f)
# Out:
# (0.5036674816625918+0.02444987775061125j)

# %%
'''
Using Built-in Functions 
Python provides several functions to work with complex numbers, such as: 
 abs(z): Returns the magnitude (absolute value) of the complex number. 
 conj(z): Returns the complex conjugate of the number. 
 
 '''

# %%
c
# Out:
# (2+3j)

# %%
print(abs(c))
print(c.conj())
# Out:
# 3.605551275463989
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 2
#       1 print(abs(c))
# ----> 2 print(e.conj())
#
# AttributeError: 'complex' object has no attribute 'conj'

# %%
'''Complex Number in the cmath Module 
The cmath module provides additional functionality for complex numbers, such as 
trigonometric functions, logarithms, and square roots. 
 '''

# %%
c
# Out:
# (2+3j)

# %%
import cmath
print(cmath.phase(c))
print(cmath.polar(c))
print(cmath.sqrt(c))
# Out:
# 0.982793723247329
# (3.605551275463989, 0.982793723247329)
# (1.6741492280355401+0.8959774761298381j)

# %%
''' Complex numbers are written with j or J for the imaginary part. 
 You can perform basic arithmetic operations on complex numbers. 
 You can access the real and imaginary parts using .real and .imag. 
 The cmath module offers additional functions for complex numbers.'''

# %% [markdown]
# BOOLEAN

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 true
#
# NameError: name 'true' is not defined

# %%
True
# Out:
# True

# %%
false
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 false
#
# NameError: name 'false' is not defined

# %%
False
# Out:
# False

# %%
True + False#in memory True means 1 and False means 0 ..> 1+0
# Out:
# 1

# %%
True + True#1 + 1
# Out:
# 2

# %%
i < f
# Out:
# False

# %%
b = (i == c)
type(b)
# Out:
# bool

# %%
b
# Out:
# False

# %%
'''python has several error
they are calssified as 3 parts
compile time
runtime
logical.....> we see this in exceptional handling'''
